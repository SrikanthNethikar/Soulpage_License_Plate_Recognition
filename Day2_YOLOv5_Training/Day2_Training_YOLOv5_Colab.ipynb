# %% [markdown]
# ## Clone YOLOv5 Repository from GitHub
#
# To begin training, we need to clone the official YOLOv5 repository from GitHub. This includes all necessary scripts like `train.py`, `detect.py`, and utility functions and installed all the required Python libraries for YOLOv5 to work properly inside Google Colab, such as PyTorch, matplotlib, seaborn, etc.

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17496, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 17496 (delta 2), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17496/17496), 16.59 MiB | 11.93 MiB/s, done.
# Resolving deltas: 100% (11993/11993), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.1 MB/s eta 0:00:00
# ...

# %%
#We use `nvidia-smi` to confirm whether a GPU is allocated to this Colab runtime. YOLOv5 training is significantly faster with GPU (T4 or better).
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# Thu Jul  3 09:17:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62a9a124-86b0-4d9f-bdd2-1982a6596333" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62a9a124-86b0-4d9f-bdd2-1982a6596333">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip license_plate_dataset.zip -d dataset/
# Out:
# Archive:  license_plate_dataset.zip
#    creating: dataset/license_plate_dataset/
#   inflating: dataset/license_plate_dataset/data.yaml
#    creating: dataset/license_plate_dataset/images/
#    creating: dataset/license_plate_dataset/images/train/
#   inflating: dataset/license_plate_dataset/images/train/1.jpg
#   inflating: dataset/license_plate_dataset/images/train/10.jpg
#   inflating: dataset/license_plate_dataset/images/train/100.jpg
#   inflating: dataset/license_plate_dataset/images/train/101.jpg
#   inflating: dataset/license_plate_dataset/images/train/102.jpg
#   inflating: dataset/license_plate_dataset/images/train/103.jpg
#   inflating: dataset/license_plate_dataset/images/train/104.jpg
#   inflating: dataset/license_plate_dataset/images/train/105.jpg
#   inflating: dataset/license_plate_dataset/images/train/106.jpg
#   inflating: dataset/license_plate_dataset/images/train/107.jpg
#   inflating: dataset/license_plate_dataset/images/train/108.jpg
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17496, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 17496 (delta 2), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17496/17496), 16.54 MiB | 28.95 MiB/s, done.
# Resolving deltas: 100% (11990/11990), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !ls /content/dataset/license_plate_dataset/
# Out:
# data.yaml  images  labels

# %%
yaml_text = """
train: /content/dataset/license_plate_dataset/images/train
val: /content/dataset/license_plate_dataset/images/val

nc: 1
names: ['license_plate']
"""

with open('/content/dataset/license_plate_dataset/data.yaml', 'w') as f:
    f.write(yaml_text)

# %%
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
#
# nc: 1
# names: ['license_plate']

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:25:25.530583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751549125.550830   13549 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751549125.557073   13549 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !nvidia-smi
# Out:
# Thu Jul  3 13:27:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls /content/dataset/license_plate_dataset
# Out:
# data.yaml  images  labels

# %%
yaml_text = """
train: /content/dataset/license_plate_dataset/images/train
val: /content/dataset/license_plate_dataset/images/val

nc: 1
names: ['license_plate']
"""

# Overwrite and save data.yaml
with open('/content/dataset/license_plate_dataset/data.yaml', 'w') as f:
    f.write(yaml_text)

# Confirm it's correct
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
#
# nc: 1
# names: ['license_plate']

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:32:20.538187: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751549540.559198   15360 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751549540.565222   15360 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
#
# nc: 1
# names: ['license_plate']

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !ls /content/dataset/license_plate_dataset
# Out:
# data.yaml  images  labels

# %%
# !ls /content/dataset/license_plate_dataset/images/train | head
# Out:
# 100.jpg
# 101.jpg
# 102.jpg
# 103.jpg
# 104.jpg
# 105.jpg
# 106.jpg
# 107.jpg
# 108.jpg
# 109.jpg

# %%
# !ls /content/dataset/license_plate_dataset/labels/train | head
# Out:
# 100.txt
# 101.txt
# 102.txt
# 103.txt
# 104.txt
# 105.txt
# 106.txt
# 107.txt
# 108.txt
# 109.txt

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
#
# nc: 1
# names: ['license_plate']

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:40:51.577960: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751550051.598322   17544 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751550051.604501   17544 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
#
# nc: 1
# names: ['license_plate']

# %%
yaml_text = """train: /content/dataset/license_plate_dataset/images/train
val: /content/dataset/license_plate_dataset/images/val
nc: 1
names: ['license_plate']
"""

with open('/content/dataset/license_plate_dataset/data.yaml', 'w') as f:
    f.write(yaml_text)

# Confirm content is clean
# !cat /content/dataset/license_plate_dataset/data.yaml
# Out:
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/val
# nc: 1
# names: ['license_plate']

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:44:25.301892: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751550265.321530   18482 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751550265.327445   18482 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !ls /content/dataset/license_plate_dataset/images/train | head
# !ls /content/dataset/license_plate_dataset/labels/train | head
# Out:
# 100.jpg
# 101.jpg
# 102.jpg
# 103.jpg
# 104.jpg
# 105.jpg
# 106.jpg
# 107.jpg
# 108.jpg
# 109.jpg
# 100.txt
# 101.txt
# 102.txt
# 103.txt
# 104.txt
# 105.txt
# 106.txt
# 107.txt
# 108.txt
# 109.txt

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 1 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name check_debug --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:47:24.488542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751550444.508100   19278 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751550444.514101   19278 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 1 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name check_debug --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-03 13:48:15.943027: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751550495.963029   19528 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751550495.969176   19528 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# %%writefile /content/dataset/license_plate_dataset/data.yaml
# train: /content/dataset/license_plate_dataset/images/train
# val: /content/dataset/license_plate_dataset/images/train
#
# nc: 1
# names: ['license_plate']
# Out:
# Overwriting /content/dataset/license_plate_dataset/data.yaml

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/license_plate_dataset/data.yaml --weights yolov5s.pt --name lp_detector
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        8/49      4.73G    0.02723   0.007397          0         27        640:   7% 4/57 [00:01<00:15,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/49      4.73G    0.02744   0.007763          0         30        640:   9% 5/57 [00:01<00:16,  3.07it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/49      4.73G    0.02724     0.0079          0         30        640:  11% 6/57 [00:01<00:17,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
